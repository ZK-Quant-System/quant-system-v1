# %%
#不带timeperiod
import pickle
data_file=open('market_data_with_double_index.pkl','rb')
data=pickle.load(data_file)
import talib
data['HT_DCPERIOD']=talib.HT_DCPERIOD(data['close'])#Cycle Indicators
data['HT_DCPHASE']=talib.HT_DCPHASE(data['close'])#Cycle Indicators
data['HT_PHASOR_inphase'],data['HT_PHASOR_quadrature']=talib.HT_PHASOR(data['close'])#Cycle Indicators
data['HT_SINE_sine'],data['HT_SINE_leadsine']=talib.HT_SINE(data['close'])#Cycle Indicators
data['HT_TRENDMODE']=talib.HT_TRENDMODE(data['close'])#Cycle Indicators
data['HT_TRENDLINE']=talib.HT_TRENDLINE(data['close'])#Overlap Studies
data['MAMA_mama'],data['MAMA_fama']=talib.MAMA(data['close'],fastlimit=0.5,slowlimit=0.05)#Overlap Studies
data['SAR']=talib.SAR(data['high'],data['low'],acceleration=0.02, maximum=0.2)#Overlap Studies
data['SAREXT']=talib.SAREXT(data['high'],data['low'],startvalue=0, offsetonreverse=0, accelerationinitlong=0.02, accelerationlong=0.2, accelerationmaxlong=0.02, accelerationinitshort=0.02, accelerationshort=0.02, accelerationmaxshort=0.2)#Overlap Studies
data['TRANGE']=talib.TRANGE(data['high'],data['low'],data['close'])#Volatility Indicators
data['AD']=talib.AD(data['high'],data['low'],data['close'],data['volume'])#Volume Indicators
data['OBV']=talib.OBV(data['close'],data['volume'])#Volume Indicators
data['BOP']=talib.BOP(data['open'],data['high'],data['low'],data['close'])#Momentum Indicators
data['CDL2CROWS']=talib.CDL2CROWS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDL3BLACKCROWS']=talib.CDL3BLACKCROWS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDL3INSIDE']=talib.CDL3INSIDE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDL3LINESTRIKE']=talib.CDL3LINESTRIKE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDL3OUTSIDE']=talib.CDL3OUTSIDE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDL3STARSINSOUTH']=talib.CDL3STARSINSOUTH(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDL3WHITESOLDIERS']=talib.CDL3WHITESOLDIERS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLABANDONEDBABY']=talib.CDLABANDONEDBABY(data['open'],data['high'],data['low'],data['close'],penetration=0.3)#Pattern Recognition
data['CDLADVANCEBLOCK']=talib.CDLADVANCEBLOCK(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLBELTHOLD']=talib.CDLBELTHOLD(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLBREAKAWAY']=talib.CDLBREAKAWAY(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLCLOSINGMARUBOZU']=talib.CDLCLOSINGMARUBOZU(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLCONCEALBABYSWALL']=talib.CDLCONCEALBABYSWALL(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLCOUNTERATTACK']=talib.CDLCOUNTERATTACK(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLDARKCLOUDCOVER']=talib.CDLDARKCLOUDCOVER(data['open'],data['high'],data['low'],data['close'],penetration=0.5)#Pattern Recognition
data['CDLDOJI']=talib.CDLDOJI(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLDOJISTAR']=talib.CDLDOJISTAR(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLDRAGONFLYDOJI']=talib.CDLDRAGONFLYDOJI(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLENGULFING']=talib.CDLENGULFING(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLEVENINGDOJISTAR']=talib.CDLEVENINGDOJISTAR(data['open'],data['high'],data['low'],data['close'],penetration=0.3)#Pattern Recognition
data['CDLEVENINGSTAR']=talib.CDLEVENINGSTAR(data['open'],data['high'],data['low'],data['close'],penetration=0.3)#Pattern Recognition
data['CDLGAPSIDESIDEWHITE']=talib.CDLGAPSIDESIDEWHITE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLGRAVESTONEDOJI']=talib.CDLGRAVESTONEDOJI(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHAMMER']=talib.CDLHAMMER(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHANGINGMAN']=talib.CDLHANGINGMAN(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHARAMI']=talib.CDLHARAMI(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHARAMICROSS']=talib.CDLHARAMICROSS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHIGHWAVE']=talib.CDLHIGHWAVE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHIKKAKE']=talib.CDLHIKKAKE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHIKKAKEMOD']=talib.CDLHIKKAKEMOD(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLHOMINGPIGEON']=talib.CDLHOMINGPIGEON(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLIDENTICAL3CROWS']=talib.CDLIDENTICAL3CROWS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLINNECK']=talib.CDLINNECK(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLINVERTEDHAMMER']=talib.CDLINVERTEDHAMMER(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLKICKING']=talib.CDLKICKING(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLKICKINGBYLENGTH']=talib.CDLKICKINGBYLENGTH(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLLADDERBOTTOM']=talib.CDLLADDERBOTTOM(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLLONGLEGGEDDOJI']=talib.CDLLONGLEGGEDDOJI(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLLONGLINE']=talib.CDLLONGLINE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLMARUBOZU']=talib.CDLMARUBOZU(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLMATCHINGLOW']=talib.CDLMATCHINGLOW(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLMATHOLD']=talib.CDLMATHOLD(data['open'],data['high'],data['low'],data['close'],penetration=0.5)#Pattern Recognition
data['CDLMORNINGDOJISTAR']=talib.CDLMORNINGDOJISTAR(data['open'],data['high'],data['low'],data['close'],penetration=0.3)#Pattern Recognition
data['CDLMORNINGSTAR']=talib.CDLMORNINGSTAR(data['open'],data['high'],data['low'],data['close'],penetration=0.3)#Pattern Recognition
data['CDLONNECK']=talib.CDLONNECK(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLPIERCING']=talib.CDLPIERCING(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLRICKSHAWMAN']=talib.CDLRICKSHAWMAN(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLRISEFALL3METHODS']=talib.CDLRISEFALL3METHODS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLSEPARATINGLINES']=talib.CDLSEPARATINGLINES(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLSHOOTINGSTAR']=talib.CDLSHOOTINGSTAR(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLSHORTLINE']=talib.CDLSHORTLINE(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLSPINNINGTOP']=talib.CDLSPINNINGTOP(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLSTALLEDPATTERN']=talib.CDLSTALLEDPATTERN(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLSTICKSANDWICH']=talib.CDLSTICKSANDWICH(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLTAKURI']=talib.CDLTAKURI(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLTASUKIGAP']=talib.CDLTASUKIGAP(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLTHRUSTING']=talib.CDLTHRUSTING(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLTRISTAR']=talib.CDLTRISTAR(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLUNIQUE3RIVER']=talib.CDLUNIQUE3RIVER(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLUPSIDEGAP2CROWS']=talib.CDLUPSIDEGAP2CROWS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data['CDLXSIDEGAP3METHODS']=talib.CDLXSIDEGAP3METHODS(data['open'],data['high'],data['low'],data['close'])#Pattern Recognition
data.to_csv('tech_file1.csv')

# %%
#带timeperiod
import pickle
data_file=open('market_data_with_double_index.pkl','rb')
data=pickle.load(data_file)
import talib
for j in range(0,1800):#每一只股票
    stocks=data.iloc[j:871200:1800]
       
    stocks['BBANDS_upperband'],stocks['BBANDS_middleband'],stocks['BBANDS_lowerband']=talib.BBANDS(stocks['close'],timeperiod=5,nbdevup=2,nbdevdn=2,matype=0)#Overlap Studies
    stocks['DEMA']=talib.DEMA(stocks['close'],timeperiod=30)#Overlap Studies
    stocks['EMA']=talib.EMA(stocks['close'],timeperiod=30)#Overlap Studies
    stocks['KAMA']=talib.KAMA(stocks['close'],timeperiod=30)#Overlap Studies
    stocks['MA']=talib.MA(stocks['close'],timeperiod=30,matype=0)#Overlap Studies
    #stocks['MAVP']=talib.MAVP(stocks['close'],stocks['date'],minperiod=2, maxperiod=30, matype=0)#Overlap Studies
    stocks['MIDPOINT']=talib.MIDPOINT(stocks['close'],timeperiod=14)#Overlap Studies
    stocks['MIDPRICE']=talib.MIDPRICE(stocks['high'],stocks['low'],timeperiod=14)#Overlap Studies
    stocks['SMA']=talib.SMA(stocks['close'],timeperiod=30)#Overlap Studies
    stocks['T3']=talib.T3(stocks['close'],timeperiod=5,vfactor=0.7)#Overlap Studies
    stocks['TEMA']=talib.TEMA(stocks['close'],timeperiod=30)#Overlap Studies
    stocks['TRIMA']=talib.TRIMA(stocks['close'],timeperiod=30)#Overlap Studies
    stocks['WMA']=talib.WMA(stocks['close'],timeperiod=30)#Overlap Studies
    
    stocks['ATR']=talib.ATR(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Volatility Indicators
    stocks['NATR']=talib.NATR(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Volatility Indicators
    
    stocks['ATR']=talib.ATR(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Volatility Indicators
    stocks['NATR']=talib.NATR(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Volatility Indicators
    
    stocks['ADOSC']=talib.ADOSC(stocks['high'],stocks['low'],stocks['close'],stocks['volume'],fastperiod=3,slowperiod=10)#Volume Indicators
    
    stocks['ADX']=talib.ADX(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['ADXR']=talib.ADXR(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['APO']=talib.APO(stocks['close'],fastperiod=12,slowperiod=26,matype=0)#Momentum Indicators
    stocks['AROON_aroondown'],stocks['AROON_aroondown']=talib.AROON(stocks['high'],stocks['low'],timeperiod=14)#Momentum Indicators
    stocks['AROONOSC']=talib.AROONOSC(stocks['high'],stocks['low'],timeperiod=14)#Momentum Indicators
    stocks['CCI']=talib.CCI(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['CMO']=talib.CMO(stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['DX']=talib.DX(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['MACD_macd'],stocks['MACD_macdsignal'],stocks['MACD_macdhist']=talib.MACD(stocks['close'],fastperiod=12,slowperiod=26,signalperiod=9)#Momentum Indicators
    stocks['MACDEXT_macd'],stocks['MACDEXT_macdsignal'],stocks['MACDEXT_macdhist']=talib.MACDEXT(stocks['close'],fastperiod=12,fastmatype=0,slowperiod=26,slowmatype=0,signalperiod=9,signalmatype=0)#Momentum Indicators
    stocks['MACDFIX_macd'],stocks['MACDFIX_macdsignal'],stocks['MACDFIX_macdhist']=talib.MACDFIX(stocks['close'],signalperiod=9)#Momentum Indicators
    stocks['MFI']=talib.MFI(stocks['high'],stocks['low'],stocks['close'],stocks['volume'],timeperiod=14)#Momentum Indicators
    stocks['MINUS_DI']=talib.MINUS_DI(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['MINUS_DM']=talib.MINUS_DM(stocks['high'],stocks['low'],timeperiod=14)#Momentum Indicators
    stocks['MOM']=talib.MOM(stocks['close'],timeperiod=10)#Momentum Indicators
    stocks['PLUS_DI']=talib.PLUS_DI(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['PLUS_DM']=talib.PLUS_DM(stocks['high'],stocks['low'],timeperiod=14)#Momentum Indicators
    stocks['PPO']=talib.PPO(stocks['close'],fastperiod=12,slowperiod=26,matype=0)#Momentum Indicators
    stocks['ROC']=talib.ROC(stocks['close'],timeperiod=10)#Momentum Indicators
    stocks['ROCP']=talib.ROCP(stocks['close'],timeperiod=10)#Momentum Indicators
    stocks['ROCR']=talib.ROCR(stocks['close'],timeperiod=10)#Momentum Indicators
    stocks['ROCR100']=talib.ROCR100(stocks['close'],timeperiod=10)#Momentum Indicators
    stocks['RSI']=talib.RSI(stocks['close'],timeperiod=14)#Momentum Indicators
    stocks['STOCH_slowk'],stocks['STOCH_slowd']=talib.STOCH(stocks['high'],stocks['low'],stocks['close'],fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#Momentum Indicators
    stocks['STOCHF_fastk'],stocks['STOCHF_fastd']=talib.STOCHF(stocks['high'],stocks['low'],stocks['close'],fastk_period=5,fastd_period=3,fastd_matype=0 )#Momentum Indicators
    stocks['STOCHRSI_fastk'],stocks['STOCHRSI_fastd']=talib.STOCHRSI(stocks['close'],timeperiod=14,fastk_period=5,fastd_period=3,fastd_matype=0)#Momentum Indicators
    stocks['TRIX']=talib.TRIX(stocks['close'],timeperiod=30)#Momentum Indicators
    stocks['ULTOSC']=talib.ULTOSC(stocks['high'],stocks['low'],stocks['close'],timeperiod1=7,timeperiod2=14,timeperiod3=28)#Momentum Indicators
    stocks['WILLR']=talib.WILLR(stocks['high'],stocks['low'],stocks['close'],timeperiod=14)#Momentum Indicators
    
    stocks.to_csv('tech_file2.csv',mode='a+')
